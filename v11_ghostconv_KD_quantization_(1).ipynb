# %% [markdown]
# <a href="https://colab.research.google.com/github/mrbrownnn/smart_traffic_lights/blob/AI_branch/v11_ghostconv_KD_quantization_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #INIT FUNC

# %%
from google.colab import drive
drive.mount('/content/drive')
PROJECT_DIR = "/content/drive/MyDrive/yolo_ghostblock"
# !mkdir -p {PROJECT_DIR}
# %cd {PROJECT_DIR}
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/yolo_ghostblock

# %%
from ultralytics.nn.modules.conv import GhostConv
from ultralytics.nn.modules.block import C3k2, C2PSA

print("GhostConv OK", GhostConv)
print("C3k2 OK", C3k2)
print("C2PSA OK", C2PSA)
# Out:
# GhostConv OK <class 'ultralytics.nn.modules.conv.GhostConv'>
# C3k2 OK <class 'ultralytics.nn.modules.block.C3k2'>
# C2PSA OK <class 'ultralytics.nn.modules.block.C2PSA'>

# %%
# !pip uninstall -y ultralytics
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics
# !pip install -e .
# Out:
# WARNING: Skipping ultralytics as it is not installed.
# fatal: destination path 'ultralytics' already exists and is not an empty directory.
# /content/drive/MyDrive/yolo_ghostblock/ultralytics
# Obtaining file:///content/drive/MyDrive/yolo_ghostblock/ultralytics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (2.9.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (0.24.0+cu126)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics==8.3.237) (1.31.0)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics==8.3.237)
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics==8.3.237) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.237) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.237) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.237) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics==8.3.237) (2025.11.12)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics==8.3.237) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.3.237) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics==8.3.237) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics==8.3.237) (3.0.3)
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Building wheels for collected packages: ultralytics
#   Building editable for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.3.237-0.editable-py3-none-any.whl size=23191 sha256=3e20ff09ca4550adaa9f626f3d7912aead15a5c315a20d38f93beb466317a2cd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-10r3t5bg/wheels/e7/ac/7f/5271eb9b987d33b3b337f9b100bf492e8652d3ea4b80c1dafb
# Successfully built ultralytics
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.237 ultralytics-thop-2.0.18

# %% [markdown]
# #CUSTOM FUNCTION
# - rewrite .yaml file
# - override ultralytics repository

# %%
from pathlib import Path

yaml_path = Path("ultralytics/ultralytics/cfg/models/v11/yolo11_tinyghost.yaml")
yaml_path.parent.mkdir(parents=True, exist_ok=True)

yaml_path.write_text("""
# YOLO11 TinyGhost – optimized lightweight model
# For 5 classes (traffic dataset)

nc: 5

scales:
  n: [0.5, 0.2, 1024]

backbone:
  - [-1, 1, GhostConv, [64, 3, 2]]
  - [-1, 1, GhostConv, [128, 3, 2]]

  - [-1, 1, C3k2, [256, False, 0.25]]

  - [-1, 1, GhostConv, [256, 3, 2]]

  - [-1, 1, C3k2, [512, False, 0.25]]

  - [-1, 1, GhostConv, [512, 3, 2]]

  - [-1, 1, C3k2, [512, True]]

  - [-1, 1, GhostConv, [1024, 3, 2]]

  - [-1, 1, C3k2, [1024, True]]

  - [-1, 1, SPPF, [1024, 5]]

  - [-1, 1, C2PSA, [1024]]

head:
  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 6], 1, Concat, [1]]
  - [-1, 1, C3k2, [512, False]]

  - [-1, 1, nn.Upsample, [None, 2, "nearest"]]
  - [[-1, 4], 1, Concat, [1]]
  - [-1, 1, C3k2, [256, False]]

  - [-1, 1, Conv, [256, 3, 2]]
  - [[-1, 13], 1, Concat, [1]]
  - [-1, 1, C3k2, [512, False]]

  - [-1, 1, Conv, [512, 3, 2]]
  - [[-1, 10], 1, Concat, [1]]
  - [-1, 1, C3k2, [1024, True]]

  - [[16, 19, 22], 1, Detect, [nc]]
""")

print("YAML written to:", yaml_path)
# Out:
# YAML written to: ultralytics/ultralytics/cfg/models/v11/yolo11_tinyghost.yaml

# %%
from ultralytics import YOLO

model = YOLO("/content/ultralytics/ultralytics/cfg/models/v11/yolo11_tinyghost.yaml")
model.info()
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# YOLO11_tinyghost summary: 191 layers, 1,656,715 parameters, 1,656,699 gradients, 4.4 GFLOPs
# (191, 1656715, 1656699, 4.4415232)

# %%
DATASET_DIR = "/content/drive/MyDrive/dataset/yolo_mtid_motor/dataset"
model.train(
    data = f"{DATASET_DIR}/data.yaml",
    epochs=50,
    imgsz=640,
    device=0,
    cache=True,
    amp=True,
    cos_lr=True,
    resume=True,
    lr0=5e-5,
    patience=10,
    warmup_epochs=10,
    project=PROJECT_DIR,
    name="v11_custom_ghostblock"
)
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=5e-05, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/ultralytics/ultralytics/cfg/models/v11/yolo11_tinyghost.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=v11_custom_ghostblock, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_ghostblock, rect=False, resume=None, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=10, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 16.5MB/s 0.0s
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       448  ultralytics.nn.modules.conv.GhostConv        [3, 16, 3, 2]
#   1                  -1  1      2768  ultralytics.nn.modules.conv.GhostConv        [16, 32, 3, 2]
#   2                  -1  1      5222  ultralytics.nn.modules.block.C3k2            [32, 56, 1, False, 0.25]
#   3                  -1  1     14924  ultralytics.nn.modules.conv.GhostConv        [56, 56, 3, 2]
#   4                  -1  1     17498  ultralytics.nn.modules.block.C3k2            [56, 104, 1, False, 0.25]
#   5                  -1  1     50180  ultralytics.nn.modules.conv.GhostConv        [104, 104, 3, 2]
#   6                  -1  1     57616  ultralytics.nn.modules.block.C3k2            [104, 104, 1, True]
#   7                  -1  1    100360  ultralytics.nn.modules.conv.GhostConv        [104, 208, 3, 2]
#   8                  -1  1    228800  ultralytics.nn.modules.block.C3k2            [208, 208, 1, True]
#   9                  -1  1    108784  ultralytics.nn.modules.block.SPPF            [208, 208, 5]
#  10                  -1  1    165464  ultralytics.nn.modules.block.C2PSA           [208, 208, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     73580  ultralytics.nn.modules.block.C3k2            [312, 104, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     23716  ultralytics.nn.modules.block.C3k2            [208, 56, 1, False]
#  17                  -1  1     28336  ultralytics.nn.modules.conv.Conv             [56, 56, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     57772  ultralytics.nn.modules.block.C3k2            [160, 104, 1, False]
#  20                  -1  1     97552  ultralytics.nn.modules.conv.Conv             [104, 104, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    250432  ultralytics.nn.modules.block.C3k2            [312, 208, 1, True]
#  23        [16, 19, 22]  1    373263  ultralytics.nn.modules.head.Detect           [5, [56, 104, 208]]
# YOLO11_tinyghost summary: 191 layers, 1,656,715 parameters, 1,656,699 gradients, 4.4 GFLOPs
#
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 61.1MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 0.3±0.2 MB/s, size: 83.8 KB)
# train: Scanning /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/train... 4316 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4316/4316 16.4it/s 4:24
# train: New cache created: /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/train.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (2.9GB RAM): 100% ━━━━━━━━━━━━ 4316/4316 420.4it/s 10.3s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 1.7±2.6 ms, read: 0.1±0.1 MB/s, size: 30.9 KB)
# val: Scanning /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/val... 2388 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2388/2388 17.6it/s 2:16
# val: New cache created: /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/val.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (1.7GB RAM): 100% ━━━━━━━━━━━━ 2388/2388 466.0it/s 5.1s
# Plotting labels to /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=5e-05' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 86 weight(decay=0.0), 93 weight(decay=0.0005), 92 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      2.42G       4.29      4.308      3.592        304        640: 100% ━━━━━━━━━━━━ 270/270 4.2it/s 1:05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 3.2it/s 23.8s
#                    all       2388      22872      0.463     0.0735     0.0365     0.0115
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      2.59G        2.4      2.126      1.922        281        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.692      0.277      0.257      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      2.75G      1.782      1.443      1.432        304        640: 100% ━━━━━━━━━━━━ 270/270 8.6it/s 31.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.0it/s 9.4s
#                    all       2388      22872      0.883      0.346       0.41      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      2.93G      1.525      1.167      1.262        233        640: 100% ━━━━━━━━━━━━ 270/270 8.7it/s 30.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872      0.913      0.387      0.477      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      2.94G      1.355     0.9945      1.157        273        640: 100% ━━━━━━━━━━━━ 270/270 8.7it/s 31.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.1s
#                    all       2388      22872      0.909      0.433      0.521      0.358
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      2.95G      1.232     0.8735      1.096        302        640: 100% ━━━━━━━━━━━━ 270/270 9.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.2s
#                    all       2388      22872      0.948      0.478      0.565      0.397
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      2.96G      1.148     0.7865      1.054        369        640: 100% ━━━━━━━━━━━━ 270/270 8.9it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.1it/s 9.3s
#                    all       2388      22872      0.898      0.552      0.623      0.455
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      2.96G      1.084     0.7274      1.024        294        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.1s
#                    all       2388      22872      0.796      0.615      0.657      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.14G      1.021     0.6819          1        244        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.0it/s 9.4s
#                    all       2388      22872      0.806      0.645       0.69      0.516
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.15G      1.003     0.6526      0.986        272        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.804      0.656      0.699      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.16G     0.9583     0.6236     0.9695        270        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.2s
#                    all       2388      22872      0.789      0.681      0.715      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.34G      0.918     0.5935     0.9536        329        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.2s
#                    all       2388      22872      0.835      0.696      0.739      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.35G     0.8903     0.5705     0.9462        282        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872      0.827      0.705       0.74      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.36G     0.8747     0.5557     0.9374        241        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.2s
#                    all       2388      22872      0.837      0.728      0.767      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      3.37G     0.8447     0.5371     0.9259        304        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872      0.809      0.751      0.776      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50      3.38G     0.8285     0.5225     0.9199        312        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 29.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.832       0.75      0.778      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50      3.39G     0.8026     0.5086      0.913        243        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.844      0.768      0.795      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       3.4G     0.7887     0.4988     0.9087        243        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872      0.867       0.77      0.793      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50      3.41G     0.7856     0.4907     0.9036        331        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.875      0.782      0.814      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50      3.42G     0.7652     0.4801     0.8993        247        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.873      0.794      0.818      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50      3.43G     0.7487     0.4706     0.8954        248        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872       0.89      0.793      0.825      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50      3.44G      0.746     0.4656     0.8925        272        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.1s
#                    all       2388      22872      0.894      0.804      0.831      0.627
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50      3.45G     0.7301     0.4558      0.889        184        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.6it/s 8.7s
#                    all       2388      22872      0.895      0.801      0.833      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50      3.46G      0.712     0.4449     0.8828        228        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 9.0s
#                    all       2388      22872      0.897      0.807      0.839      0.639
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50      3.46G     0.7129     0.4447     0.8833        376        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.909      0.806      0.842      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50      3.47G     0.7043      0.442     0.8798        265        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.6it/s 8.8s
#                    all       2388      22872      0.906      0.814      0.848       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50      3.49G     0.6917     0.4339     0.8773        343        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.2it/s 9.1s
#                    all       2388      22872      0.913      0.816      0.851      0.655
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50      3.49G     0.6789     0.4269     0.8729        283        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.925        0.8      0.851      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       3.5G     0.6763     0.4223     0.8723        313        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 29.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872       0.91      0.811      0.852      0.654
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50      3.51G     0.6655     0.4172     0.8702        259        640: 100% ━━━━━━━━━━━━ 270/270 9.0it/s 29.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.918      0.824      0.855      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50      3.52G     0.6623     0.4157     0.8689        252        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.1it/s 9.3s
#                    all       2388      22872       0.91      0.827      0.859      0.661
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50      3.53G     0.6532     0.4092     0.8667        331        640: 100% ━━━━━━━━━━━━ 270/270 8.9it/s 30.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872      0.917      0.837      0.868      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50      3.54G     0.6457     0.4037     0.8637        179        640: 100% ━━━━━━━━━━━━ 270/270 8.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 9.0s
#                    all       2388      22872      0.911      0.836      0.864      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50      3.55G     0.6389     0.4001      0.863        241        640: 100% ━━━━━━━━━━━━ 270/270 8.9it/s 30.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.916      0.834      0.868      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50      3.56G     0.6356     0.3988     0.8627        279        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 9.0s
#                    all       2388      22872      0.922      0.837      0.869      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50      3.57G     0.6275      0.395     0.8616        280        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872       0.92      0.849      0.875      0.683
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50      3.58G     0.6212     0.3904       0.86        248        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872      0.924       0.84      0.873       0.68
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50      3.59G      0.619     0.3896     0.8584        334        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872      0.917      0.843      0.875      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50       3.6G     0.6125     0.3853     0.8567        244        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.3it/s 9.0s
#                    all       2388      22872      0.925      0.846      0.877      0.689
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50      3.61G     0.6062     0.3811     0.8548        363        640: 100% ━━━━━━━━━━━━ 270/270 9.2it/s 29.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.921      0.847      0.874      0.689
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50      3.62G     0.5829     0.3753     0.8471        148        640: 100% ━━━━━━━━━━━━ 270/270 9.1it/s 29.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.914       0.84       0.87      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50      3.63G     0.5645     0.3605     0.8435        144        640: 100% ━━━━━━━━━━━━ 270/270 9.6it/s 28.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872      0.918       0.85      0.876      0.692
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50      3.64G     0.5567     0.3557     0.8409        164        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 9.0s
#                    all       2388      22872      0.919      0.848      0.877      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50      3.65G     0.5495     0.3525     0.8403        169        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 8.9s
#                    all       2388      22872      0.922      0.848       0.88      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50      3.66G     0.5408     0.3474     0.8394        154        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.6it/s 8.8s
#                    all       2388      22872      0.914      0.855      0.881      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50      3.67G     0.5431     0.3496     0.8387        143        640: 100% ━━━━━━━━━━━━ 270/270 9.3it/s 28.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.4it/s 9.0s
#                    all       2388      22872      0.924      0.852      0.879      0.698
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50      3.68G     0.5329     0.3436     0.8375        158        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872      0.923      0.854      0.881      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50      3.69G     0.5341     0.3429     0.8369        141        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.8s
#                    all       2388      22872       0.92      0.855      0.881      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50       3.7G     0.5315     0.3424     0.8385        190        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.5it/s 8.9s
#                    all       2388      22872      0.922      0.855      0.882      0.701
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50      3.71G     0.5331      0.344     0.8394        171        640: 100% ━━━━━━━━━━━━ 270/270 9.4it/s 28.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 8.6it/s 8.7s
#                    all       2388      22872      0.923      0.855      0.882      0.702
#
# 50 epochs completed in 0.557 hours.
# Optimizer stripped from /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/last.pt, 3.6MB
# Optimizer stripped from /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/best.pt, 3.6MB
#
# Validating /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 6.5it/s 11.5s
#                    all       2388      22872      0.924      0.855      0.882      0.702
#                    car       2388      13494      0.984      0.961      0.976      0.856
#                bicycle       1278       1582       0.87      0.826      0.886      0.586
#                    bus       1376       1550      0.988      0.981      0.994      0.942
#                  truck       1624       5252      0.983      0.982      0.992        0.9
#              motorbike        666        994      0.796      0.523      0.563      0.225
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3, 4])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7feed420a960>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[          1,           1,           1, ...,    0.021274,    0.010637,           0],
#        [          1,           1,           1, ...,   0.0023291,   0.0011645,           0],
#        [          1,           1,           1, ...,     0.77895,     0.16282,           0],
#        [          1,           1,           1, ...,    0.063903,    0.031951,           0],
#        [          1,           1,           1, ...,  8.8795e-05,  4.4398e-05,           0]]), 'Recall', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
# ...
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[     0.2701,      0.2701,     0.34197, ...,           1,           1,           1],
#        [   0.075009,    0.075009,     0.10922, ...,           1,           1,           1],
#        [    0.31481,     0.31481,     0.55968, ...,           1,           1,           1],
#        [    0.27349,     0.27349,     0.37298, ...,           1,           1,           1],
#        [   0.013074,    0.013074,    0.022663, ...,           1,           1,           1]]), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.97458,     0.97458,     0.97414, ...,           0,           0,           0],
#        [    0.93552,     0.93552,     0.93489, ...,           0,           0,           0],
#        [    0.99806,     0.99806,     0.99806, ...,           0,           0,           0],
#        [    0.99143,     0.99143,     0.99105, ...,           0,           0,           0],
#        [    0.70523,     0.70523,     0.69718, ...,           0,           0,           0]]), 'Confidence', 'Recall']]
# fitness: np.float64(0.7017928169110751)
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([     0.8557,     0.58618,      0.9418,     0.90012,     0.22517])
# names: {0: 'car', 1: 'bicycle', 2: 'bus', 3: 'truck', 4: 'motorbike'}
# nt_per_class: array([13494,  1582,  1550,  5252,   994])
# nt_per_image: array([2388, 1278, 1376, 1624,  666])
# results_dict: {'metrics/precision(B)': 0.9239796444054885, 'metrics/recall(B)': 0.8547325920476565, 'metrics/mAP50(B)': 0.8824472022195969, 'metrics/mAP50-95(B)': 0.7017928169110751, 'fitness': 0.7017928169110751}
# save_dir: PosixPath('/content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock')
# speed: {'preprocess': 0.08298627721955537, 'inference': 0.45924840368444136, 'loss': 0.00025500041871113035, 'postprocess': 0.8431961721115211}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}
# task: 'detect'

# %% [markdown]
# #DISTILLATION KNOWLEDGE FUNCTION

# %%
"""
Knowledge Distillation Trainer for YOLO11 Models.

This module implements a custom trainer for distilling knowledge from a large
teacher model to a smaller student model using feature-based and logit-based
distillation techniques.
"""

import torch
import torch.nn as nn
import torch.nn.functional as F
from typing import Dict, Optional, Tuple, Any, List

from ultralytics import YOLO
from ultralytics.models.yolo.detect import DetectionTrainer
from ultralytics.utils import RANK


# =========================
# Configuration Constants
# =========================
class KDConfig:
    """Configuration for Knowledge Distillation training."""

    # Model paths
    TEACHER_PATH = "/content/drive/MyDrive/teacher_models/yolo11l_original5/weights/best.pt"
    STUDENT_PATH = "/content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/best.pt"
    DATA_YAML = "/content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/data.yaml"
    PROJECT = "/content/drive/MyDrive/yolo_kd_ghost_superlight"

    # KD hyperparameters
    KD_ALPHA = 0.3          # Weight for feature distillation loss
    KD_BETA = 0.2           # Weight for logit distillation loss
    KD_TEMPERATURE = 4.0    # Temperature for soft targets
    FREEZE_LAYERS = 0       # Number of layers to freeze in student

    # Feature extraction layers (adjust based on architecture)
    KD_LAYERS = ["model.4", "model.6", "model.10"]  # P3, P4, PSA output

    # Training hyperparameters
    EPOCHS = 40
    IMAGE_SIZE = 640
    BATCH_SIZE = 16
    PATIENCE = 15


# =========================
# Knowledge Distillation Trainer
# =========================
class KnowledgeDistillationTrainer(DetectionTrainer):
    """
    Custom YOLO trainer with knowledge distillation support.

    Implements both feature-based and logit-based distillation to transfer
    knowledge from a teacher model to a student model.

    Args:
        teacher_model: Pre-trained teacher YOLO model
        kd_alpha: Weight for feature distillation loss
        kd_beta: Weight for logit distillation loss
        kd_temperature: Temperature parameter for soft targets
        kd_layers: List of layer names to extract features from
        *args: Additional arguments for DetectionTrainer
        **kwargs: Additional keyword arguments for DetectionTrainer
    """

    def __init__(
        self,
        teacher_model: YOLO,
        kd_alpha: float,
        kd_beta: float,
        kd_temperature: float,
        kd_layers: List[str],
        *args,
        **kwargs
    ):
        super().__init__(*args, **kwargs)

        # Store KD parameters
        self.teacher = teacher_model.to(self.device)
        self.kd_alpha = kd_alpha
        self.kd_beta = kd_beta
        self.kd_temperature = kd_temperature
        self.kd_layers = kd_layers

        # Freeze teacher model
        self.teacher.eval()
        for param in self.teacher.parameters():
            param.requires_grad = False

        # Feature storage dictionaries
        self.student_features: Dict[str, torch.Tensor] = {}
        self.teacher_features: Dict[str, torch.Tensor] = {}

        # Register forward hooks
    # đăng kí quá sớm
       #  self._register_feature_hooks()

        if RANK in (-1, 0):
            print(f"[KD] Initialized with layers: {self.kd_layers}")
            print(f"[KD] Alpha={kd_alpha}, Beta={kd_beta}, Temperature={kd_temperature}")

    def get_model(
        self,
        cfg: Optional[str] = None,
        weights: Optional[str] = None,
        verbose: bool = True
    ) -> nn.Module:
        """Get the student model."""
        return super().get_model(cfg, weights, verbose)

    def setup_model(self) -> None:
      """Build model and register KD hooks."""
      super().setup_model()  # kế thừa từ Trainer(Ultralytics)

      # lúc này self.model đã là YOLO nn.Module
      self._register_feature_hooks()

    if RANK in (-1, 0):
        print("[KD] Feature hooks registered after model setup")

    def _register_feature_hooks(self) -> None:
        """Register forward hooks to capture intermediate features."""

        def create_student_hook(layer_name: str):
            """Factory for student feature hooks."""
            def hook(module: nn.Module, input: Any, output: torch.Tensor) -> None:
                self.student_features[layer_name] = output
            return hook

        def create_teacher_hook(layer_name: str):
            """Factory for teacher feature hooks."""
            def hook(module: nn.Module, input: Any, output: torch.Tensor) -> None:
                self.teacher_features[layer_name] = output
            return hook

        # Register hooks for student model
        for name, module in self.model.model.named_modules():
            if name in self.kd_layers:
                module.register_forward_hook(create_student_hook(name))

        # Register hooks for teacher model
        for name, module in self.teacher.model.named_modules():
            if name in self.kd_layers:
                module.register_forward_hook(create_teacher_hook(name))

    def _extract_logits(self, model_output: Any) -> Optional[torch.Tensor]:
        """
        Extract logits tensor from YOLO model output.

        YOLO11 outputs can be in various formats:
        - Direct Tensor
        - List/tuple containing Tensor
        - Dict with 'pred' key

        Args:
            model_output: Output from YOLO forward pass

        Returns:
            Logits tensor if found, None otherwise
        """
        # Direct tensor output
        if isinstance(model_output, torch.Tensor):
            return model_output

        # Dictionary output
        if isinstance(model_output, dict):
            if "pred" in model_output and isinstance(model_output["pred"], torch.Tensor):
                return model_output["pred"]
            # Try to find any tensor value
            for value in model_output.values():
                if isinstance(value, torch.Tensor):
                    return value

        # List/tuple output
        if isinstance(model_output, (list, tuple)):
            for item in model_output:
                if isinstance(item, torch.Tensor):
                    return item
                if isinstance(item, dict) and "pred" in item:
                    if isinstance(item["pred"], torch.Tensor):
                        return item["pred"]

        return None

    def criterion(
        self,
        predictions: Any,
        batch: Dict[str, torch.Tensor]
    ) -> Tuple[torch.Tensor, torch.Tensor]:
        """
        Compute combined loss with knowledge distillation.

        Args:
            predictions: Student model predictions
            batch: Training batch

        Returns:
            Tuple of (total_loss, loss_items)
        """
        # Compute standard detection loss
        loss_hard, loss_items = super().criterion(predictions, batch)

        # Get images
        images = batch["img"].to(self.device, non_blocking=True)

        # Get teacher predictions
        with torch.no_grad():
            teacher_predictions = self.teacher(images)

        # Compute distillation losses
        loss_feature = self._compute_feature_distillation()
        loss_logit = self._compute_logit_distillation(predictions, teacher_predictions)

        # Combine losses with weights
        kd_warmup_epochs = 8

        if self.epoch < kd_warmup_epochs:
         # Early epochs: ONLY hard loss (GT)
          total_loss = loss_hard
        else:
          # After warm-up: hard + KD
          total_loss = (
        (1.0 - self.kd_alpha - self.kd_beta) * loss_hard +
        self.kd_alpha * loss_feature +
        self.kd_beta * loss_logit
        )

        return total_loss, loss_items

    def _compute_feature_distillation(self) -> torch.Tensor:
        """
        Compute feature-based distillation loss.

        Uses normalized MSE loss between student and teacher features
        at specified intermediate layers.

        Returns:
            Average feature distillation loss
        """
        if not self.student_features or not self.teacher_features:
            return torch.tensor(0.0, device=self.device)

        total_loss = 0.0
        valid_layers = 0

        for layer_name in self.kd_layers:
            if layer_name not in self.student_features or layer_name not in self.teacher_features:
                continue

            student_feat = self.student_features[layer_name]
            teacher_feat = self.teacher_features[layer_name]

            # Skip if shapes don't match
            if student_feat.shape != teacher_feat.shape:
                continue

            # Normalize features: [B, C, H, W] -> [B, C, H*W]
            student_norm = F.normalize(student_feat.flatten(2), dim=1)
            teacher_norm = F.normalize(teacher_feat.flatten(2), dim=1)

            # Compute MSE loss
            total_loss += F.mse_loss(student_norm, teacher_norm)
            valid_layers += 1

        if valid_layers == 0:
            return torch.tensor(0.0, device=self.device)

        return total_loss / valid_layers

    def _compute_logit_distillation(
        self,
        student_output: Any,
        teacher_output: Any
    ) -> torch.Tensor:
        """
        Compute logit-based distillation loss using KL divergence.

        Args:
            student_output: Student model predictions
            teacher_output: Teacher model predictions

        Returns:
            KL divergence loss between soft targets
        """
        # Extract logits
        student_logits = self._extract_logits(student_output)
        teacher_logits = self._extract_logits(teacher_output)

        if student_logits is None or teacher_logits is None:
            return torch.tensor(0.0, device=self.device)

        # Skip if shapes don't match
        if student_logits.shape != teacher_logits.shape:
            return torch.tensor(0.0, device=self.device)

        # Apply temperature scaling
        temp = self.kd_temperature

        # Compute soft targets with KL divergence
        student_soft = F.log_softmax(student_logits / temp, dim=-1)
        teacher_soft = F.softmax(teacher_logits / temp, dim=-1)

        # Scale loss by temperature squared
        loss = F.kl_div(student_soft, teacher_soft, reduction="batchmean") * (temp ** 2)

        return loss


# =========================
# Utility Functions
# =========================
def create_kd_trainer_class(
    teacher_model: YOLO,
    kd_alpha: float,
    kd_beta: float,
    kd_temperature: float,
    kd_layers: List[str]
) -> type:
    """
    Create a custom KD trainer class with specified parameters.

    Args:
        teacher_model: Pre-trained teacher model
        kd_alpha: Feature distillation weight
        kd_beta: Logit distillation weight
        kd_temperature: Temperature for soft targets
        kd_layers: Layers for feature extraction

    Returns:
        Custom trainer class
    """
    class CustomKDTrainer(KnowledgeDistillationTrainer):
        def __init__(self, *args, **kwargs):
            super().__init__(
                teacher_model=teacher_model,
                kd_alpha=kd_alpha,
                kd_beta=kd_beta,
                kd_temperature=kd_temperature,
                kd_layers=kd_layers,
                *args,
                **kwargs
            )

    return CustomKDTrainer


def freeze_model_layers(model: YOLO, num_layers: int = 10) -> int:
    """
    Freeze the first N layers of the model.

    For new architectures like GhostSuperLight, it's recommended to use
    few frozen layers (0-5) to allow adaptation.

    Args:
        model: YOLO model to freeze
        num_layers: Number of modules to freeze

    Returns:
        Number of parameters frozen
    """
    if num_layers <= 0:
        return 0

    frozen_count = 0
    for idx, (name, module) in enumerate(model.model.named_modules()):
        if idx >= num_layers:
            break

        for param in module.parameters():
            param.requires_grad = False
            frozen_count += 1

    return frozen_count


# =========================
# Main Training Script
# =========================
def main():
    """Execute knowledge distillation training."""
    print("=" * 70)
    print("Knowledge Distillation Training for YOLO11n-GhostSuperLight")
    print("=" * 70)

    # Load configuration
    config = KDConfig()

    # 1. Load teacher model
    print("\n[1/5] Loading teacher model...")
    teacher = YOLO(config.TEACHER_PATH)
    print(f"      Teacher loaded: {config.TEACHER_PATH}")

    # 2. Load student model
    print("\n[2/5] Loading student model...")
    student = YOLO(config.STUDENT_PATH)
    print(f"      Student loaded: {config.STUDENT_PATH}")

    # 3. Optionally freeze student backbone
    if config.FREEZE_LAYERS > 0:
        print(f"\n[3/5] Freezing first {config.FREEZE_LAYERS} layers...")
        num_frozen = freeze_model_layers(student, config.FREEZE_LAYERS)
        print(f"      Frozen {num_frozen} parameters")
    else:
        print("\n[3/5] No layer freezing (recommended for new architectures)")

    # 4. Create KD trainer class
    print("\n[4/5] Creating knowledge distillation trainer...")
    TrainerClass = create_kd_trainer_class(
        teacher_model=teacher,
        kd_alpha=config.KD_ALPHA,
        kd_beta=config.KD_BETA,
        kd_temperature=config.KD_TEMPERATURE,
        kd_layers=config.KD_LAYERS
    )

    # 5. Initialize and start training
    print("\n[5/5] Starting training...")
    trainer = TrainerClass(
        overrides={
            "model": config.STUDENT_PATH,
            "data": config.DATA_YAML,
            "epochs": config.EPOCHS,
            "imgsz": config.IMAGE_SIZE,
            "batch": config.BATCH_SIZE,
            "project": config.PROJECT,
            "name": "kd_ghost_superlight_v1",
            "device": 0,
            "patience": config.PATIENCE,
            "save": True,
            "verbose": True,
        }
    )

    trainer.train()

    print("\n" + "=" * 70)
    print("Knowledge Distillation Training Completed!")
    print("=" * 70)


if __name__ == '__main__':
    main()
# Out:
# [KD] Feature hooks registered after model setup
# ======================================================================
# Knowledge Distillation Training for YOLO11n-GhostSuperLight
# ======================================================================
#
# [1/5] Loading teacher model...
#       Teacher loaded: /content/drive/MyDrive/teacher_models/yolo11l_original5/weights/best.pt
#
# [2/5] Loading student model...
#       Student loaded: /content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/best.pt
#
# [3/5] No layer freezing (recommended for new architectures)
#
# [4/5] Creating knowledge distillation trainer...
#
# [5/5] Starting training...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=40, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolo_ghostblock/v11_custom_ghostblock/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=kd_ghost_superlight_v13, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_kd_ghost_superlight, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# [KD] Initialized with layers: ['model.4', 'model.6', 'model.10']
# [KD] Alpha=0.3, Beta=0.2, Temperature=4.0
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       448  ultralytics.nn.modules.conv.GhostConv        [3, 16, 3, 2]
#   1                  -1  1      2768  ultralytics.nn.modules.conv.GhostConv        [16, 32, 3, 2]
#   2                  -1  1      5222  ultralytics.nn.modules.block.C3k2            [32, 56, 1, False, 0.25]
#   3                  -1  1     14924  ultralytics.nn.modules.conv.GhostConv        [56, 56, 3, 2]
#   4                  -1  1     17498  ultralytics.nn.modules.block.C3k2            [56, 104, 1, False, 0.25]
#   5                  -1  1     50180  ultralytics.nn.modules.conv.GhostConv        [104, 104, 3, 2]
#   6                  -1  1     57616  ultralytics.nn.modules.block.C3k2            [104, 104, 1, True]
#   7                  -1  1    100360  ultralytics.nn.modules.conv.GhostConv        [104, 208, 3, 2]
#   8                  -1  1    228800  ultralytics.nn.modules.block.C3k2            [208, 208, 1, True]
#   9                  -1  1    108784  ultralytics.nn.modules.block.SPPF            [208, 208, 5]
#  10                  -1  1    165464  ultralytics.nn.modules.block.C2PSA           [208, 208, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     73580  ultralytics.nn.modules.block.C3k2            [312, 104, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     23716  ultralytics.nn.modules.block.C3k2            [208, 56, 1, False]
#  17                  -1  1     28336  ultralytics.nn.modules.conv.Conv             [56, 56, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     57772  ultralytics.nn.modules.block.C3k2            [160, 104, 1, False]
#  20                  -1  1     97552  ultralytics.nn.modules.conv.Conv             [104, 104, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    250432  ultralytics.nn.modules.block.C3k2            [312, 208, 1, True]
#  23        [16, 19, 22]  1    373263  ultralytics.nn.modules.head.Detect           [5, [56, 104, 208]]
# YOLO11_tinyghost summary: 191 layers, 1,656,715 parameters, 1,656,699 gradients, 4.4 GFLOPs
#
# Transferred 529/529 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.4±0.1 ms, read: 51.2±34.4 MB/s, size: 74.8 KB)
# train: Scanning /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/train.cache... 4316 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 4316/4316 6.5Mit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 3.4±6.2 ms, read: 19.1±17.3 MB/s, size: 34.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/yolo_mtid_motor/dataset/labels/val.cache... 2388 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 2388/2388 3.1Mit/s 0.0s
# Plotting labels to /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 86 weight(decay=0.0), 93 weight(decay=0.0005), 92 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13
# Starting training for 40 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/40      2.75G     0.6259     0.3897     0.8609        216        640: 100% ━━━━━━━━━━━━ 270/270 6.8it/s 39.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.9s
#                    all       2388      22872      0.926      0.846      0.879      0.684
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/40      2.75G     0.6517     0.4043     0.8633        287        640: 100% ━━━━━━━━━━━━ 270/270 7.9it/s 34.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.928      0.844      0.878      0.663
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/40      2.75G     0.6613      0.409     0.8634        323        640: 100% ━━━━━━━━━━━━ 270/270 7.9it/s 34.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.5it/s 10.0s
#                    all       2388      22872      0.917      0.838      0.876      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/40      2.75G     0.6666     0.4096      0.864        283        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.9s
#                    all       2388      22872      0.919      0.833      0.873      0.665
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/40      2.75G     0.6563     0.4036     0.8613        237        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.923      0.836      0.876      0.667
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/40      2.75G     0.6526     0.4042     0.8618        326        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.4it/s 10.2s
#                    all       2388      22872      0.911      0.845      0.877      0.668
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/40      2.75G     0.6424     0.3969     0.8605        275        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.924       0.85      0.884      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/40      2.75G     0.6417     0.3977     0.8591        210        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.931      0.853      0.888      0.686
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/40      2.75G     0.6373     0.3951     0.8579        273        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.9s
#                    all       2388      22872      0.929      0.859      0.888      0.687
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/40      2.75G     0.6295     0.3887     0.8541        259        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.918      0.858      0.886      0.679
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/40      2.75G     0.6223     0.3869     0.8527        294        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872       0.94      0.856      0.893      0.699
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/40      2.75G     0.6207     0.3856     0.8537        252        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872       0.93      0.859       0.89      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/40      2.75G     0.6215      0.386     0.8528        222        640: 100% ━━━━━━━━━━━━ 270/270 7.9it/s 34.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.929       0.87      0.894      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/40      2.75G     0.6095     0.3788       0.85        246        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872      0.942      0.859      0.898      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/40      2.75G     0.6133     0.3803     0.8513        262        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.7s
#                    all       2388      22872      0.932      0.868      0.897       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/40      2.75G     0.5936     0.3685     0.8462        284        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.7s
#                    all       2388      22872      0.933      0.874      0.901      0.716
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/40      2.75G     0.5906     0.3669     0.8453        207        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.5it/s 10.0s
#                    all       2388      22872      0.933      0.869      0.897      0.706
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/40      2.75G     0.5945     0.3696     0.8469        157        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872      0.939       0.87      0.899      0.711
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/40      2.75G     0.5928      0.367     0.8456        299        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.3it/s 10.3s
#                    all       2388      22872       0.94      0.872      0.899      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/40      2.75G     0.5833     0.3632     0.8431        270        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.936      0.874      0.901      0.713
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/40      2.75G     0.5783     0.3613     0.8435        138        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872       0.94      0.879      0.905      0.708
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/40      2.75G     0.5849     0.3609     0.8439        255        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.7s
#                    all       2388      22872      0.942      0.879      0.905      0.723
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/40      2.94G     0.5691     0.3533       0.84        258        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.7s
#                    all       2388      22872      0.939      0.872      0.902       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/40      2.94G     0.5666     0.3543     0.8392        328        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.948      0.877      0.911      0.721
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/40      2.94G     0.5671     0.3578     0.8402        281        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872      0.935      0.881      0.905      0.718
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/40      2.94G      0.569     0.3598     0.8401        265        640: 100% ━━━━━━━━━━━━ 270/270 7.9it/s 34.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.7s
#                    all       2388      22872      0.944      0.884      0.909      0.729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/40      2.94G     0.5661     0.3593     0.8384        291        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.8s
#                    all       2388      22872      0.941      0.881      0.907      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/40      2.94G     0.5583     0.3546      0.838        240        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.945      0.884       0.91      0.735
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/40      2.94G     0.5584     0.3543     0.8372        297        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.4it/s 10.1s
#                    all       2388      22872       0.95       0.88      0.911      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/40      2.94G      0.548       0.35     0.8352        242        640: 100% ━━━━━━━━━━━━ 270/270 8.0it/s 33.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.946      0.884      0.912      0.735
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/40      2.94G     0.5303     0.3401      0.828        123        640: 100% ━━━━━━━━━━━━ 270/270 7.9it/s 34.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.4it/s 10.1s
#                    all       2388      22872      0.941      0.878      0.904      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/40      2.94G     0.5125     0.3288     0.8241        155        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.5it/s 10.0s
#                    all       2388      22872      0.949      0.883       0.91      0.732
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/40      2.94G     0.5016     0.3223     0.8235        112        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.6s
#                    all       2388      22872      0.949      0.882      0.911      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/40      2.94G     0.4932     0.3186     0.8226        126        640: 100% ━━━━━━━━━━━━ 270/270 8.3it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.9s
#                    all       2388      22872      0.955      0.879      0.914      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/40      2.94G     0.4831      0.313      0.821        120        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.952      0.888      0.915      0.739
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/40      2.94G     0.4822     0.3121     0.8215        147        640: 100% ━━━━━━━━━━━━ 270/270 8.1it/s 33.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.8it/s 9.7s
#                    all       2388      22872      0.953      0.885      0.914      0.742
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/40      2.94G     0.4749     0.3087     0.8189        121        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.6it/s 9.9s
#                    all       2388      22872      0.961      0.883      0.915      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/40      2.94G     0.4763     0.3085     0.8191        101        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 33.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.7it/s 9.8s
#                    all       2388      22872      0.955      0.885      0.915      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/40      2.94G      0.468     0.3062     0.8193        162        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.4it/s 10.1s
#                    all       2388      22872      0.952      0.889      0.915      0.747
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/40      2.94G     0.4641     0.3024      0.818        134        640: 100% ━━━━━━━━━━━━ 270/270 8.2it/s 33.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 7.5it/s 10.0s
#                    all       2388      22872      0.953      0.888      0.916      0.746
#
# 40 epochs completed in 0.489 hours.
# Optimizer stripped from /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/weights/last.pt, 3.6MB
# Optimizer stripped from /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/weights/best.pt, 3.6MB
#
# Validating /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 75/75 6.1it/s 12.3s
#                    all       2388      22872      0.951      0.889      0.914      0.747
#                    car       2388      13494      0.992      0.964      0.979      0.887
#                bicycle       1278       1582      0.941      0.891      0.935      0.657
#                    bus       1376       1550      0.997      0.991      0.995      0.956
#                  truck       1624       5252      0.993      0.985      0.994      0.923
#              motorbike        666        994      0.833      0.613      0.669      0.314
# Speed: 0.1ms preprocess, 0.5ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13
#
# ======================================================================
# Knowledge Distillation Training Completed!
# ======================================================================

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

results_path = os.path.join(
    "/content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v12",
    "results.csv"
)

df = pd.read_csv(results_path)

plt.figure(figsize=(10, 6))
plt.plot(
    df['epoch'],
    df['metrics/mAP50(B)'],
    linestyle='-',
    marker='o',
    markersize=4,
    linewidth=2,
    label='mAP@0.5'
)

# mAP@0.5:0.95: nét đứt + marker tam giác
plt.plot(
    df['epoch'],
    df['metrics/mAP50-95(B)'],
    linestyle='--',
    marker='^',
    markersize=4,
    linewidth=2,
    label='mAP@0.5:0.95'
)

plt.xlabel('Epoch')
plt.ylabel('mAP')
plt.title('Training Progress of mAP Metrics')
plt.legend()
plt.grid(True, linestyle=':', linewidth=0.8)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))
f1 = 2 * (df['metrics/precision(B)'] * df['metrics/recall(B)']) / (df['metrics/precision(B)'] + df['metrics/recall(B)'])
plt.plot(df['epoch'], f1, label='F1 Score', color='purple')
plt.xlabel('Epoch')
plt.ylabel('F1 Score')
plt.title('F1 Curve')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# ===== Box Loss =====
plt.plot(
    df['epoch'], df['train/box_loss'],
    linestyle='-', marker='o', markersize=4, linewidth=2,
    label='Train Box Loss'
)
plt.plot(
    df['epoch'], df['val/box_loss'],
    linestyle='--', marker='o', markersize=4, linewidth=2,
    label='Val Box Loss'
)

# ===== Class Loss =====
plt.plot(
    df['epoch'], df['train/cls_loss'],
    linestyle='-', marker='s', markersize=4, linewidth=2,
    label='Train Class Loss'
)
plt.plot(
    df['epoch'], df['val/cls_loss'],
    linestyle='--', marker='s', markersize=4, linewidth=2,
    label='Val Class Loss'
)

# ===== DFL Loss =====
plt.plot(
    df['epoch'], df['train/dfl_loss'],
    linestyle='-', marker='^', markersize=4, linewidth=2,
    label='Train DFL Loss'
)
plt.plot(
    df['epoch'], df['val/dfl_loss'],
    linestyle='--', marker='^', markersize=4, linewidth=2,
    label='Val DFL Loss'
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Curves of YOLOv11')
plt.legend(ncol=2)
plt.grid(True, linestyle=':', linewidth=0.8)
plt.tight_layout()
plt.show()

# %% [markdown]
# #finetune function

# %%
model = YOLO("/content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/weights/best.pt")
model.info()

results = model.train(
    data=f"{"/content/drive/MyDrive/dataset/3_data_multi_view_intersection"}/data.yaml",
    epochs=50,
    imgsz=640,
    device=0,
    cache=True,
    amp=True,
    cos_lr=True,
    resume=False,
    lr0=1e-5, #learning rate
    patience=10,
    warmup_epochs=5,
    freeze = 3,
    project=PROJECT_DIR,
    name="yolo11n_pruned_ft"
)
# Out:
# YOLO11_tinyghost summary: 191 layers, 1,656,715 parameters, 0 gradients, 4.4 GFLOPs
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=3, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=1e-05, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/drive/MyDrive/yolo_kd_ghost_superlight/kd_ghost_superlight_v13/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n_pruned_ft6, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/drive/MyDrive/yolo_ghostblock, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=5, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       448  ultralytics.nn.modules.conv.GhostConv        [3, 16, 3, 2]
#   1                  -1  1      2768  ultralytics.nn.modules.conv.GhostConv        [16, 32, 3, 2]
#   2                  -1  1      5222  ultralytics.nn.modules.block.C3k2            [32, 56, 1, False, 0.25]
#   3                  -1  1     14924  ultralytics.nn.modules.conv.GhostConv        [56, 56, 3, 2]
#   4                  -1  1     17498  ultralytics.nn.modules.block.C3k2            [56, 104, 1, False, 0.25]
#   5                  -1  1     50180  ultralytics.nn.modules.conv.GhostConv        [104, 104, 3, 2]
#   6                  -1  1     57616  ultralytics.nn.modules.block.C3k2            [104, 104, 1, True]
#   7                  -1  1    100360  ultralytics.nn.modules.conv.GhostConv        [104, 208, 3, 2]
#   8                  -1  1    228800  ultralytics.nn.modules.block.C3k2            [208, 208, 1, True]
#   9                  -1  1    108784  ultralytics.nn.modules.block.SPPF            [208, 208, 5]
#  10                  -1  1    165464  ultralytics.nn.modules.block.C2PSA           [208, 208, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     73580  ultralytics.nn.modules.block.C3k2            [312, 104, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     23716  ultralytics.nn.modules.block.C3k2            [208, 56, 1, False]
#  17                  -1  1     28336  ultralytics.nn.modules.conv.Conv             [56, 56, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     57772  ultralytics.nn.modules.block.C3k2            [160, 104, 1, False]
#  20                  -1  1     97552  ultralytics.nn.modules.conv.Conv             [104, 104, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    250432  ultralytics.nn.modules.block.C3k2            [312, 208, 1, True]
#  23        [16, 19, 22]  1    373263  ultralytics.nn.modules.head.Detect           [5, [56, 104, 208]]
# YOLO11_tinyghost summary: 191 layers, 1,656,715 parameters, 1,656,699 gradients, 4.4 GFLOPs
#
# Transferred 529/529 items from pretrained weights
# Freezing layer 'model.0.cv1.conv.weight'
# Freezing layer 'model.0.cv1.bn.weight'
# Freezing layer 'model.0.cv1.bn.bias'
# Freezing layer 'model.0.cv2.conv.weight'
# Freezing layer 'model.0.cv2.bn.weight'
# Freezing layer 'model.0.cv2.bn.bias'
# Freezing layer 'model.1.cv1.conv.weight'
# Freezing layer 'model.1.cv1.bn.weight'
# Freezing layer 'model.1.cv1.bn.bias'
# Freezing layer 'model.1.cv2.conv.weight'
# Freezing layer 'model.1.cv2.bn.weight'
# Freezing layer 'model.1.cv2.bn.bias'
# Freezing layer 'model.2.cv1.conv.weight'
# Freezing layer 'model.2.cv1.bn.weight'
# Freezing layer 'model.2.cv1.bn.bias'
# Freezing layer 'model.2.cv2.conv.weight'
# Freezing layer 'model.2.cv2.bn.weight'
# Freezing layer 'model.2.cv2.bn.bias'
# Freezing layer 'model.2.m.0.cv1.conv.weight'
# Freezing layer 'model.2.m.0.cv1.bn.weight'
# Freezing layer 'model.2.m.0.cv1.bn.bias'
# Freezing layer 'model.2.m.0.cv2.conv.weight'
# Freezing layer 'model.2.m.0.cv2.bn.weight'
# Freezing layer 'model.2.m.0.cv2.bn.bias'
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.3±0.0 ms, read: 45.7±21.4 MB/s, size: 97.8 KB)
# train: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/train/labels.cache... 5805 images, 219 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5805/5805 8.0Mit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (6.6GB RAM): 100% ━━━━━━━━━━━━ 5805/5805 119.1it/s 48.7s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 30.4±15.4 MB/s, size: 72.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 491.8Kit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.6GB RAM): 100% ━━━━━━━━━━━━ 549/549 501.1it/s 1.1s
# Plotting labels to /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=1e-05' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 86 weight(decay=0.0), 93 weight(decay=0.0005), 92 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50      3.12G      2.262      2.291      1.718        274        640: 100% ━━━━━━━━━━━━ 363/363 8.1it/s 44.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.8it/s 2.3s
#                    all        549       5438      0.412      0.368      0.374       0.22
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50      3.12G      1.651      1.305      1.314        197        640: 100% ━━━━━━━━━━━━ 363/363 9.3it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438      0.635      0.487      0.531      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50      3.12G      1.539      1.177      1.254        134        640: 100% ━━━━━━━━━━━━ 363/363 9.7it/s 37.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.8it/s 2.3s
#                    all        549       5438      0.723      0.528        0.6      0.379
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50      3.12G      1.474      1.093      1.216        121        640: 100% ━━━━━━━━━━━━ 363/363 9.9it/s 36.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.751      0.534       0.64      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50      3.12G      1.427      1.044      1.193        173        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.2s
#                    all        549       5438      0.774      0.568      0.679      0.433
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50      3.12G      1.393     0.9942      1.169        106        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438       0.77      0.612      0.703      0.449
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50      3.12G      1.368     0.9662      1.151        235        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.801      0.638       0.73      0.475
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50      3.12G      1.346     0.9311      1.139        147        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.831      0.658       0.75       0.49
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50      3.12G      1.323     0.9155      1.125        217        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.826      0.671       0.76      0.504
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50      3.12G      1.309     0.9011      1.119        158        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.3s
#                    all        549       5438      0.838      0.678      0.769      0.512
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50      3.12G      1.295     0.8815      1.108        101        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.3s
#                    all        549       5438      0.849      0.695      0.788      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50      3.12G       1.27     0.8594      1.103        175        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.847      0.693      0.787      0.528
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50      3.12G      1.262      0.855      1.094        158        640: 100% ━━━━━━━━━━━━ 363/363 9.9it/s 36.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.827      0.717      0.795      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50      3.12G       1.26     0.8446      1.088        165        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438      0.854      0.709      0.811      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50      3.12G      1.243     0.8281      1.083        217        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.863      0.708      0.812      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50       3.3G      1.237     0.8235      1.081        206        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438      0.832      0.741      0.818      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50       3.3G      1.225     0.8105      1.075        172        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.2s
#                    all        549       5438      0.857      0.745      0.829      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50       3.3G       1.22     0.7984      1.066        157        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.861      0.741       0.82       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50       3.3G      1.212     0.7942      1.065        128        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.3it/s 2.2s
#                    all        549       5438       0.84      0.749      0.829      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50       3.3G      1.204     0.7884      1.061        223        640: 100% ━━━━━━━━━━━━ 363/363 10.0it/s 36.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.859      0.758      0.836      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50       3.3G      1.192     0.7732      1.057        201        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.3s
#                    all        549       5438      0.862      0.748      0.834      0.581
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50       3.3G      1.186     0.7706      1.052        134        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438       0.85      0.761      0.842      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50       3.3G      1.175     0.7625      1.047        139        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.2s
#                    all        549       5438      0.837      0.777      0.843      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50       3.3G      1.167     0.7501      1.043        224        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.848      0.773      0.847       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50       3.3G      1.167     0.7444      1.038        270        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.847      0.786      0.844      0.594
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50       3.3G      1.159     0.7379      1.035        184        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.845       0.78      0.849       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50       3.3G      1.152     0.7335      1.035        143        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.3it/s 2.2s
#                    all        549       5438      0.874      0.766      0.853      0.598
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50       3.3G      1.142     0.7241      1.031        203        640: 100% ━━━━━━━━━━━━ 363/363 9.8it/s 36.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.3s
#                    all        549       5438      0.868      0.782      0.858      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50       3.3G      1.141     0.7225      1.028        161        640: 100% ━━━━━━━━━━━━ 363/363 9.3it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438       0.88      0.785       0.86      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50       3.3G      1.133     0.7119      1.024        145        640: 100% ━━━━━━━━━━━━ 363/363 9.3it/s 39.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.2s
#                    all        549       5438       0.88       0.79      0.862      0.605
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50       3.3G      1.137     0.7142      1.026        178        640: 100% ━━━━━━━━━━━━ 363/363 9.1it/s 39.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.0it/s 2.2s
#                    all        549       5438      0.874      0.784      0.861      0.606
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50       3.3G      1.123     0.7048      1.021        159        640: 100% ━━━━━━━━━━━━ 363/363 9.3it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.8it/s 2.3s
#                    all        549       5438      0.876      0.785      0.864      0.613
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50       3.3G      1.124     0.7036      1.018        117        640: 100% ━━━━━━━━━━━━ 363/363 9.2it/s 39.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.854      0.796      0.863      0.612
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50       3.3G      1.116     0.6975      1.015        124        640: 100% ━━━━━━━━━━━━ 363/363 9.3it/s 39.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.857      0.803      0.864      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50       3.3G      1.109     0.6935      1.016        178        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.854      0.814      0.867       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50       3.3G      1.104     0.6886      1.013        156        640: 100% ━━━━━━━━━━━━ 363/363 9.9it/s 36.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.876      0.801      0.868      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50       3.3G      1.098      0.682       1.01        208        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.2s
#                    all        549       5438      0.855      0.814      0.868       0.62
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50       3.3G        1.1     0.6846      1.013        242        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.874      0.795      0.869      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50       3.3G      1.091     0.6757      1.008        207        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.875      0.797      0.871      0.623
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50       3.3G      1.089     0.6754      1.007        162        640: 100% ━━━━━━━━━━━━ 363/363 9.9it/s 36.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438      0.876      0.813      0.874      0.626
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50       3.3G       1.04     0.6305      1.004         72        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.876      0.799      0.872      0.624
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50       3.3G      1.031     0.6188      1.002        168        640: 100% ━━━━━━━━━━━━ 363/363 10.0it/s 36.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.868      0.816      0.873       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50       3.3G      1.028     0.6161      1.001         94        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.5it/s 2.1s
#                    all        549       5438      0.878       0.81      0.877       0.63
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50       3.3G       1.02     0.6107     0.9987         89        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.6it/s 2.1s
#                    all        549       5438      0.883      0.809      0.876      0.633
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50       3.3G      1.019     0.6074     0.9977         86        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.5it/s 2.1s
#                    all        549       5438      0.892      0.804      0.879      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50       3.3G      1.013     0.6041     0.9929        140        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 36.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.881      0.819      0.881      0.637
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50       3.3G      1.014     0.6042     0.9943        107        640: 100% ━━━━━━━━━━━━ 363/363 10.4it/s 34.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.884      0.812       0.88      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50       3.3G      1.009      0.601     0.9902        114        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.888      0.809      0.881      0.638
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50       3.3G       1.01     0.6003     0.9908        140        640: 100% ━━━━━━━━━━━━ 363/363 10.1it/s 35.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.2it/s 2.2s
#                    all        549       5438      0.884      0.812      0.881      0.635
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50       3.3G      1.011     0.6013     0.9943        115        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.3it/s 2.2s
#                    all        549       5438      0.882      0.812      0.881      0.638
#
# 50 epochs completed in 0.544 hours.
# Optimizer stripped from /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/last.pt, 3.6MB
# Optimizer stripped from /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt, 3.6MB
#
# Validating /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.7it/s 3.8s
#                    all        549       5438      0.886      0.812       0.88      0.637
#                    car        520       3842        0.9      0.892      0.948      0.708
#                bicycle        189        250      0.908      0.784      0.854      0.639
#                    bus         81        108      0.859      0.889      0.924      0.746
#              motorbike        331       1238      0.876      0.682      0.795      0.457
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# Construct the path to the results.csv file
results_path = os.path.join("/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6", "results.csv")

# Read the results.csv file into a pandas DataFrame
df = pd.read_csv(results_path)

fig, axes = plt.subplots(3, 2, figsize=(14, 14))

axes[0,0].plot(df['epoch'], df['train/box_loss'], label='Train Box Loss')
axes[0,0].plot(df['epoch'], df['val/box_loss'], label='Val Box Loss')
axes[0,0].set_title('Box Loss'); axes[0,0].legend(); axes[0,0].grid()

axes[0,1].plot(df['epoch'], df['train/cls_loss'], label='Train Cls Loss')
axes[0,1].plot(df['epoch'], df['val/cls_loss'], label='Val Cls Loss')
axes[0,1].set_title('Class Loss'); axes[0,1].legend(); axes[0,1].grid()

axes[1,0].plot(df['epoch'], df['metrics/mAP50(B)'], label='mAP50')
axes[1,0].plot(df['epoch'], df['metrics/mAP50-95(B)'], label='mAP50-95')
axes[1,0].set_title('mAP Curves'); axes[1,0].legend(); axes[1,0].grid()

axes[1,1].plot(df['epoch'], df['metrics/precision(B)'], label='Precision')
axes[1,1].plot(df['epoch'], df['metrics/recall(B)'], label='Recall')
axes[1,1].set_title('Precision & Recall'); axes[1,1].legend(); axes[1,1].grid()

f1 = 2 * (df['metrics/precision(B)'] * df['metrics/recall(B)']) / (df['metrics/precision(B)'] + df['metrics/recall(B)'])
axes[2,0].plot(df['epoch'], f1, label='F1 Score', color='purple')
axes[2,0].set_title('F1 Curve'); axes[2,0].legend(); axes[2,0].grid()

axes[2,1].plot(df['epoch'], df['train/dfl_loss'], label='Train DFL Loss')
axes[2,1].plot(df['epoch'], df['val/dfl_loss'], label='Val DFL Loss')
axes[2,1].set_title('DFL Loss'); axes[2,1].legend(); axes[2,1].grid()


plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

results_path = os.path.join(
    "/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6",
    "results.csv"
)
df = pd.read_csv(results_path)

fig, axes = plt.subplots(3, 2, figsize=(14, 14))

# ===== Box Loss =====
axes[0,0].plot(df['epoch'], df['train/box_loss'],
               linestyle='-', marker='o', markersize=4, linewidth=2,
               label='Train Box')
axes[0,0].plot(df['epoch'], df['val/box_loss'],
               linestyle='--', marker='o', markersize=4, linewidth=2,
               label='Val Box')
axes[0,0].set_title('Box Loss')
axes[0,0].legend()
axes[0,0].grid(True, linestyle=':', linewidth=0.8)

# ===== Class Loss =====
axes[0,1].plot(df['epoch'], df['train/cls_loss'],
               linestyle='-', marker='s', markersize=4, linewidth=2,
               label='Train Class')
axes[0,1].plot(df['epoch'], df['val/cls_loss'],
               linestyle='--', marker='s', markersize=4, linewidth=2,
               label='Val Class')
axes[0,1].set_title('Classification Loss')
axes[0,1].legend()
axes[0,1].grid(True, linestyle=':', linewidth=0.8)

# ===== mAP =====
axes[1,0].plot(df['epoch'], df['metrics/mAP50(B)'],
               linestyle='-', marker='o', markersize=4, linewidth=2,
               label='mAP@0.5')
axes[1,0].plot(df['epoch'], df['metrics/mAP50-95(B)'],
               linestyle='--', marker='^', markersize=4, linewidth=2,
               label='mAP@0.5:0.95')
axes[1,0].set_title('mAP Curves')
axes[1,0].legend()
axes[1,0].grid(True, linestyle=':', linewidth=0.8)

# ===== Precision & Recall =====
axes[1,1].plot(df['epoch'], df['metrics/precision(B)'],
               linestyle='-', marker='s', markersize=4, linewidth=2,
               label='Precision')
axes[1,1].plot(df['epoch'], df['metrics/recall(B)'],
               linestyle='--', marker='^', markersize=4, linewidth=2,
               label='Recall')
axes[1,1].set_title('Precision & Recall')
axes[1,1].legend()
axes[1,1].grid(True, linestyle=':', linewidth=0.8)

# ===== F1 Score =====
f1 = 2 * (df['metrics/precision(B)'] * df['metrics/recall(B)']) / \
     (df['metrics/precision(B)'] + df['metrics/recall(B)'])

axes[2,0].plot(df['epoch'], f1,
               linestyle='-', marker='D', markersize=4, linewidth=2,
               label='F1 Score')
axes[2,0].set_title('F1 Score')
axes[2,0].legend()
axes[2,0].grid(True, linestyle=':', linewidth=0.8)

# ===== DFL Loss =====
axes[2,1].plot(df['epoch'], df['train/dfl_loss'],
               linestyle='-', marker='^', markersize=4, linewidth=2,
               label='Train DFL')
axes[2,1].plot(df['epoch'], df['val/dfl_loss'],
               linestyle='--', marker='^', markersize=4, linewidth=2,
               label='Val DFL')
axes[2,1].set_title('DFL Loss')
axes[2,1].legend()
axes[2,1].grid(True, linestyle=':', linewidth=0.8)

plt.tight_layout()
plt.show()

# %%
from ultralytics import YOLO

PT = "/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt"
DATA = "/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml"

model_fp32 = YOLO(PT)
fp32_metrics = model_fp32.val(
    data=DATA,
    imgsz=640,
    device=0
)
print("FP32 done")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 34.2±8.4 MB/s, size: 69.5 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 825.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 5.1it/s 6.9s
#                    all        549       5438      0.885      0.813      0.881      0.636
#                    car        520       3842      0.898      0.893      0.948      0.708
#                bicycle        189        250      0.903      0.784      0.855      0.639
#                    bus         81        108      0.859      0.889      0.924      0.741
#              motorbike        331       1238      0.879      0.687      0.797      0.457
# Speed: 1.0ms preprocess, 1.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/runs/detect/val
# FP32 done

# %%
from ultralytics import YOLO

PT = "/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt"
DATA = "/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml"

model_fp32 = YOLO(PT)
fp32_metrics = model_fp32.val(
    data=DATA,
    imgsz=416,
    device=0
)
print("FP32 done")
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
# val: Fast image access ✅ (ping: 0.4±0.2 ms, read: 57.6±21.8 MB/s, size: 82.0 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 852.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 5.9it/s 5.9s
#                    all        549       5438      0.883      0.745       0.83      0.586
#                    car        520       3842      0.872      0.837      0.909      0.656
#                bicycle        189        250      0.884      0.712      0.785      0.564
#                    bus         81        108      0.942       0.87       0.94      0.752
#              motorbike        331       1238      0.835       0.56      0.686      0.373
# Speed: 0.4ms preprocess, 1.6ms inference, 0.0ms loss, 2.5ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/runs/detect/val2
# FP32 done

# %%
from ultralytics import YOLO

CALIB_YAML = "/content/drive/MyDrive/dataset/cali/data.yaml"

tflite_int8 = model_fp32.export(
    format="tflite",
    int8=True,
    data=CALIB_YAML,
    imgsz=416          # test INT8
)

print("INT8 exported to:", tflite_int8)
# Out:
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
#
# PyTorch: starting from '/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt' with input shape (1, 3, 416, 416) BCHW and output shape(s) (1, 9, 3549) (3.5 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=/content/drive/MyDrive/dataset/cali/data.yaml'
# Fast image access ✅ (ping: 0.3±0.1 ms, read: 0.2±0.1 MB/s, size: 70.6 KB)
# Scanning /content/drive/MyDrive/dataset/cali/labels... 0 images, 467 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 467/467 28.7it/s 16.3s
# WARNING ⚠️ No labels found in /content/drive/MyDrive/dataset/cali/labels.cache. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
# New cache created: /content/drive/MyDrive/dataset/cali/labels.cache
# WARNING ⚠️ Labels are missing or empty in /content/drive/MyDrive/dataset/cali/labels.cache, training may not work correctly. See https://docs.ultralytics.com/datasets for dataset formatting guidance.
#
# ONNX: starting export with onnx 1.19.1 opset 22...
# ONNX: slimming with onnxslim 0.1.79...
# ONNX: export success ✅ 1.7s, saved as '/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.onnx' (6.5 MB)
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 20.1MB/s 0.1s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/drive/MyDrive/yolo_ghostblock/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 32.2files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.6...
# Saved artifact at '/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 416, 416, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 9, 3549), dtype=tf.float32, name=None)
# Captures:
#   140664627100560: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664627101136: TensorSpec(shape=(3, 3, 3, 8), dtype=tf.float32, name=None)
#   140664627101328: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   140664275635664: TensorSpec(shape=(5, 5, 8, 1), dtype=tf.float32, name=None)
#   140664275636432: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   140664275636624: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664275636816: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   140664275637968: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140664275637392: TensorSpec(shape=(5, 5, 16, 1), dtype=tf.float32, name=None)
#   140664275636048: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   140664275637008: TensorSpec(shape=(1, 1, 32, 28), dtype=tf.float32, name=None)
#   140664275638160: TensorSpec(shape=(28,), dtype=tf.float32, name=None)
#   140664275638928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275639120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275640656: TensorSpec(shape=(3, 3, 14, 7), dtype=tf.float32, name=None)
#   140664275641232: TensorSpec(shape=(7,), dtype=tf.float32, name=None)
#   140664275637776: TensorSpec(shape=(3, 3, 7, 14), dtype=tf.float32, name=None)
#   140664275637200: TensorSpec(shape=(14,), dtype=tf.float32, name=None)
#   140664275638352: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275639312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275638736: TensorSpec(shape=(1, 1, 42, 56), dtype=tf.float32, name=None)
#   140664275641424: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664275641616: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664275639504: TensorSpec(shape=(3, 3, 56, 28), dtype=tf.float32, name=None)
#   140664275642000: TensorSpec(shape=(28,), dtype=tf.float32, name=None)
#   140664275642192: TensorSpec(shape=(5, 5, 28, 1), dtype=tf.float32, name=None)
#   140664275642576: TensorSpec(shape=(28,), dtype=tf.float32, name=None)
#   140664275642768: TensorSpec(shape=(1, 1, 56, 52), dtype=tf.float32, name=None)
#   140664275640848: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664275643344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275642960: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275644880: TensorSpec(shape=(3, 3, 26, 13), dtype=tf.float32, name=None)
#   140664275645072: TensorSpec(shape=(13,), dtype=tf.float32, name=None)
#   140664275642384: TensorSpec(shape=(3, 3, 13, 26), dtype=tf.float32, name=None)
#   140664275643152: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664275640272: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275644304: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275645264: TensorSpec(shape=(1, 1, 78, 104), dtype=tf.float32, name=None)
#   140664275643728: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664275645648: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664275644112: TensorSpec(shape=(3, 3, 104, 52), dtype=tf.float32, name=None)
#   140664275645456: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664275646224: TensorSpec(shape=(5, 5, 52, 1), dtype=tf.float32, name=None)
#   140664275645840: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664275646032: TensorSpec(shape=(1, 1, 104, 104), dtype=tf.float32, name=None)
#   140664275646608: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664275646992: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275646800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275647568: TensorSpec(shape=(1, 1, 52, 26), dtype=tf.float32, name=None)
#   140664275646416: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664275644496: TensorSpec(shape=(3, 3, 26, 26), dtype=tf.float32, name=None)
#   140664275647760: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664298128016: TensorSpec(shape=(3, 3, 26, 26), dtype=tf.float32, name=None)
#   140664298129360: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664298128976: TensorSpec(shape=(3, 3, 26, 26), dtype=tf.float32, name=None)
#   140664298129552: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664298130128: TensorSpec(shape=(3, 3, 26, 26), dtype=tf.float32, name=None)
#   140664298130704: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664275648336: TensorSpec(shape=(1, 1, 52, 26), dtype=tf.float32, name=None)
#   140664275647952: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664421187408: TensorSpec(shape=(1, 1, 52, 52), dtype=tf.float32, name=None)
#   140664437379280: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664275647184: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664275647376: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664437380048: TensorSpec(shape=(1, 1, 156, 104), dtype=tf.float32, name=None)
#   140664437378896: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437379664: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664437379856: TensorSpec(shape=(3, 3, 104, 104), dtype=tf.float32, name=None)
#   140664437378128: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437380432: TensorSpec(shape=(5, 5, 104, 1), dtype=tf.float32, name=None)
#   140664437379472: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437380240: TensorSpec(shape=(1, 1, 208, 208), dtype=tf.float32, name=None)
#   140664437380816: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437381200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664437381008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664437383120: TensorSpec(shape=(1, 1, 104, 52), dtype=tf.float32, name=None)
#   140664437383312: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437382544: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664437383504: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437383696: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664437383888: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437382736: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664437384272: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437382160: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664437378704: TensorSpec(shape=(1, 1, 104, 52), dtype=tf.float32, name=None)
#   140664437384464: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437380624: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664437385040: TensorSpec(shape=(1, 1, 104, 104), dtype=tf.float32, name=None)
#   140664437384080: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437381392: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664437381584: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664437385232: TensorSpec(shape=(1, 1, 312, 208), dtype=tf.float32, name=None)
#   140664437385424: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437384656: TensorSpec(shape=(1, 1, 208, 104), dtype=tf.float32, name=None)
#   140664437385616: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437385808: TensorSpec(shape=(1, 1, 416, 208), dtype=tf.float32, name=None)
#   140664437384848: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437386192: TensorSpec(shape=(1, 1, 208, 208), dtype=tf.float32, name=None)
#   140664437386768: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437386576: TensorSpec(shape=(1, 1, 104, 208), dtype=tf.float32, name=None)
#   140664437387152: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437386384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   140664437387536: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437391184: TensorSpec(shape=(1, 1, 104, 104), dtype=tf.float32, name=None)
#   140664437388688: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664437389456: TensorSpec(shape=(1, 1, 104, 208), dtype=tf.float32, name=None)
#   140664437390224: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664437387728: TensorSpec(shape=(1, 1, 208, 104), dtype=tf.float32, name=None)
#   140664437390992: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882348304: TensorSpec(shape=(1, 1, 208, 208), dtype=tf.float32, name=None)
#   140664882348688: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664882348112: TensorSpec(shape=(1, 1, 312, 104), dtype=tf.float32, name=None)
#   140664882348880: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882349648: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882349840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882350992: TensorSpec(shape=(3, 3, 52, 26), dtype=tf.float32, name=None)
#   140664882351184: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664882350416: TensorSpec(shape=(3, 3, 26, 52), dtype=tf.float32, name=None)
#   140664882352528: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664882350032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882348496: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882351760: TensorSpec(shape=(1, 1, 156, 104), dtype=tf.float32, name=None)
#   140664882351952: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882352912: TensorSpec(shape=(1, 1, 208, 56), dtype=tf.float32, name=None)
#   140664882349072: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882352336: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882350800: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882354448: TensorSpec(shape=(3, 3, 28, 14), dtype=tf.float32, name=None)
#   140664882354640: TensorSpec(shape=(14,), dtype=tf.float32, name=None)
#   140664882352720: TensorSpec(shape=(3, 3, 14, 28), dtype=tf.float32, name=None)
#   140664882353104: TensorSpec(shape=(28,), dtype=tf.float32, name=None)
#   140664882352144: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882353296: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882354832: TensorSpec(shape=(1, 1, 84, 56), dtype=tf.float32, name=None)
#   140664882353488: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882355216: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664882353872: TensorSpec(shape=(3, 3, 56, 56), dtype=tf.float32, name=None)
#   140664882355024: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882357136: TensorSpec(shape=(1, 1, 160, 104), dtype=tf.float32, name=None)
#   140664882356560: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882357328: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882358096: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882360400: TensorSpec(shape=(3, 3, 52, 26), dtype=tf.float32, name=None)
#   140664882358288: TensorSpec(shape=(26,), dtype=tf.float32, name=None)
#   140664882360976: TensorSpec(shape=(3, 3, 26, 52), dtype=tf.float32, name=None)
#   140664882359824: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664882358672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882358864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664882360592: TensorSpec(shape=(1, 1, 156, 104), dtype=tf.float32, name=None)
#   140664882360784: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882361168: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   140664882362320: TensorSpec(shape=(3, 3, 104, 104), dtype=tf.float32, name=None)
#   140664882362512: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882363856: TensorSpec(shape=(1, 1, 312, 208), dtype=tf.float32, name=None)
#   140664882361360: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664892244048: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664892244432: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664892246736: TensorSpec(shape=(1, 1, 104, 52), dtype=tf.float32, name=None)
#   140664892244624: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892247504: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664892246160: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892248464: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664892250192: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892248080: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664892248272: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892246352: TensorSpec(shape=(3, 3, 52, 52), dtype=tf.float32, name=None)
#   140664892244816: TensorSpec(shape=(1, 1, 104, 52), dtype=tf.float32, name=None)
#   140664892249808: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892245776: TensorSpec(shape=(52,), dtype=tf.float32, name=None)
#   140664892249424: TensorSpec(shape=(1, 1, 104, 104), dtype=tf.float32, name=None)
#   140664892247888: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664892245008: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664892245200: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   140664892250000: TensorSpec(shape=(1, 1, 312, 208), dtype=tf.float32, name=None)
#   140664892248848: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664892248656: TensorSpec(shape=(3, 3, 208, 1), dtype=tf.float32, name=None)
#   140664882361552: TensorSpec(shape=(3, 3, 104, 1), dtype=tf.float32, name=None)
#   140664882355792: TensorSpec(shape=(3, 3, 56, 1), dtype=tf.float32, name=None)
#   140664892250384: TensorSpec(shape=(208,), dtype=tf.float32, name=None)
#   140664882361744: TensorSpec(shape=(104,), dtype=tf.float32, name=None)
#   140664882355984: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664892251152: TensorSpec(shape=(1, 1, 208, 56), dtype=tf.float32, name=None)
#   140664882362704: TensorSpec(shape=(1, 1, 104, 56), dtype=tf.float32, name=None)
#   140664882356752: TensorSpec(shape=(1, 1, 56, 56), dtype=tf.float32, name=None)
#   140664892249616: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882361936: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882354064: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664892250768: TensorSpec(shape=(3, 3, 56, 1), dtype=tf.float32, name=None)
#   140664892249040: TensorSpec(shape=(3, 3, 208, 64), dtype=tf.float32, name=None)
#   140664892244240: TensorSpec(shape=(3, 3, 56, 1), dtype=tf.float32, name=None)
#   140664882363088: TensorSpec(shape=(3, 3, 104, 64), dtype=tf.float32, name=None)
#   140664882357712: TensorSpec(shape=(3, 3, 56, 1), dtype=tf.float32, name=None)
#   140664882355600: TensorSpec(shape=(3, 3, 56, 64), dtype=tf.float32, name=None)
#   140664892251920: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664892249232: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664882364048: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882363280: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664882357904: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882355408: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664892252304: TensorSpec(shape=(1, 1, 56, 56), dtype=tf.float32, name=None)
#   140664892250576: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140664892247312: TensorSpec(shape=(1, 1, 56, 56), dtype=tf.float32, name=None)
#   140664882362128: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140664882358480: TensorSpec(shape=(1, 1, 56, 56), dtype=tf.float32, name=None)
#   140664882356368: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   140664892251536: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664892250960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664892246928: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882363472: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664882359440: TensorSpec(shape=(56,), dtype=tf.float32, name=None)
#   140664882356176: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664892252496: TensorSpec(shape=(1, 1, 56, 5), dtype=tf.float32, name=None)
#   140664892251344: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140664892247696: TensorSpec(shape=(1, 1, 56, 5), dtype=tf.float32, name=None)
#   140664882364240: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140664882360016: TensorSpec(shape=(1, 1, 56, 5), dtype=tf.float32, name=None)
#   140664882357520: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   140664892251728: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664892252688: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   140664882363664: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664892247120: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   140664882356944: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   140664882362896: TensorSpec(shape=(5,), dtype=tf.float32, name=None)
#   140664892253648: TensorSpec(shape=(1, 1, 16, 1), dtype=tf.float32, name=None)
#   140664892254992: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140664892252112: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140664892253456: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140664892254416: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   140664892255760: TensorSpec(shape=(1, 2, 3549), dtype=tf.float32, name=None)
#   140664892253072: TensorSpec(shape=(1, 2, 3549), dtype=tf.float32, name=None)
#
#
# TensorFlow SavedModel: export success ✅ 1295.0s, saved as '/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model' (22.0 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.19.0...
# TensorFlow Lite: export success ✅ 0.0s, saved as '/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite' (1.8 MB)
#
# Export complete (1295.2s)
# Results saved to /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite imgsz=416 int8
# Validate:        yolo val task=detect model=/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite imgsz=416 data=/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml int8
# Visualize:       https://netron.app
# INT8 exported to: /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite

# %%
from ultralytics import YOLO

# =========================
# PATHS
# =========================
FP32_MODEL = "/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best.pt"
INT8_MODEL = "/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite"
FP16_MODEL ="/content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_float16.tflite"
DATA_YAML = "/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml"

IMG_SIZE = 416  # phải giống lúc export INT8

# =========================
# FP32 EVALUATION
# =========================
print("===== Evaluating FP32 model =====")
model_fp32 = YOLO(FP32_MODEL)
fp32_metrics = model_fp32.val(
    data=DATA_YAML,
    imgsz=IMG_SIZE,
    device=0
)

# =========================
# INT8 EVALUATION
# =========================
print("\n===== Evaluating INT8 model =====")
model_int8 = YOLO(INT8_MODEL)
int8_metrics = model_int8.val(
    data=DATA_YAML,
    imgsz=IMG_SIZE,
    device=0
)
# =========================
# INT8 EVALUATION
# =========================
print("\n===== Evaluating FP16 model =====")
model_fp16 = YOLO(FP16_MODEL)
fp16_metrics = model_fp16.val(
    data=DATA_YAML,
    imgsz = IMG_SIZE,
    device=0
)
# SUMMARY
# =========================
print("\n===== SUMMARY (FP32 vs INT8) =====")

print(f"FP32  mAP50     : {fp32_metrics.box.map50:.4f}")
print(f"INT8  mAP50     : {int8_metrics.box.map50:.4f}")
print(f"Δ mAP50         : {int8_metrics.box.map50 - fp32_metrics.box.map50:+.4f}")

print(f"\nFP32  mAP50-95  : {fp32_metrics.box.map:.4f}")
print(f"INT8  mAP50-95  : {int8_metrics.box.map:.4f}")
print(f"Δ mAP50-95      : {int8_metrics.box.map - fp32_metrics.box.map:+.4f}")
#===========================

print("\n===== SUMMARY (FP32 vs FP16) =====")

print(f"FP32  mAP50     : {fp32_metrics.box.map50:.4f}")
print(f"INT8  mAP50     : {fp16_metrics.box.map50:.4f}")
print(f"Δ mAP50         : {fp16_metrics.box.map50 - fp32_metrics.box.map50:+.4f}")

print(f"\nFP32  mAP50-95  : {fp32_metrics.box.map:.4f}")
print(f"FP16  mAP50-95  : {fp16_metrics.box.map:.4f}")
print(f"Δ mAP50-95      : {fp16_metrics.box.map - fp32_metrics.box.map:+.4f}")
# Out:
# ===== Evaluating FP32 model =====
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11_tinyghost summary (fused): 105 layers, 1,650,321 parameters, 0 gradients, 4.3 GFLOPs
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 36.9±6.7 MB/s, size: 75.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 857.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 35/35 6.7it/s 5.3s
#                    all        549       5438      0.883      0.745       0.83      0.586
#                    car        520       3842      0.872      0.837      0.909      0.656
#                bicycle        189        250      0.884      0.712      0.785      0.564
#                    bus         81        108      0.942       0.87       0.94      0.752
#              motorbike        331       1238      0.835       0.56      0.686      0.373
# Speed: 0.4ms preprocess, 2.0ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/ultralytics/runs/detect/val4
#
# ===== Evaluating INT8 model =====
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Loading /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_int8.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 416, 416)
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 47.3±10.8 MB/s, size: 85.6 KB)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 876.5Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 549/549 25.9it/s 21.2s
#                    all        549       5438      0.865      0.739      0.818      0.571
#                    car        520       3842      0.866      0.826      0.899      0.641
#                bicycle        189        250      0.893        0.7      0.779      0.555
#                    bus         81        108      0.892       0.87      0.925       0.73
#              motorbike        331       1238       0.81       0.56      0.668      0.359
# Speed: 0.7ms preprocess, 28.2ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/ultralytics/runs/detect/val5
#
# ===== Evaluating FP16 model =====
# WARNING ⚠️ Unable to automatically guess model task, assuming 'task=detect'. Explicitly define task for your model, i.e. 'task=detect', 'segment', 'classify','pose' or 'obb'.
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Loading /content/drive/MyDrive/yolo_ghostblock/yolo11n_pruned_ft6/weights/best_saved_model/best_float16.tflite for TensorFlow Lite inference...
# Setting batch=1 input of shape (1, 3, 416, 416)
# val: Fast image access ✅ (ping: 0.3±0.1 ms, read: 56.0±14.3 MB/s, size: 72.5 KB)
# /usr/local/lib/python3.12/dist-packages/tensorflow/lite/python/interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 1.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 549/549 19.5it/s 28.1s
#                    all        549       5438      0.877      0.734      0.818      0.574
#                    car        520       3842      0.876      0.818      0.898      0.643
#                bicycle        189        250      0.906      0.698      0.781      0.558
#                    bus         81        108      0.894       0.87      0.928      0.734
#              motorbike        331       1238      0.831      0.549      0.666      0.358
# Speed: 0.6ms preprocess, 40.9ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to /content/drive/MyDrive/yolo_ghostblock/ultralytics/runs/detect/val6
#
# ===== SUMMARY (FP32 vs INT8) =====
# FP32  mAP50     : 0.8299
# INT8  mAP50     : 0.8178
# Δ mAP50         : -0.0121
#
# FP32  mAP50-95  : 0.5864
# INT8  mAP50-95  : 0.5714
# Δ mAP50-95      : -0.0150
#
# ===== SUMMARY (FP32 vs FP16) =====
# FP32  mAP50     : 0.8299
# INT8  mAP50     : 0.8182
# Δ mAP50         : -0.0118
#
# FP32  mAP50-95  : 0.5864
# FP16  mAP50-95  : 0.5736
# Δ mAP50-95      : -0.0128
