# %%
# !pip -q install ultralytics
from google.colab import drive
drive.mount("/content/drive")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 64.1 MB/s eta 0:00:00
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3430790521.py in <cell line: 0>()
#       1 get_ipython().system('pip -q install ultralytics')
#       2 from google.colab import drive
# ----> 3 drive.mount("/content/drive")
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     270             'https://research.google.com/colaboratory/faq.html#drive-timeout'
#     271         )
# --> 272       raise ValueError('mount failed' + extra_reason)
#     273     elif case == 4:
#     274       # Terminate the DriveFS binary before killing bash.
#
# ValueError: mount failed

# %%
from ultralytics import YOLO
model = YOLO('/content/yolo11n.pt')
results = model.train(
    data=('/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml'),
    epochs=20,
    imgsz=640,
    batch=16,
    device=0,
    workers=2,
    cache=True,
    amp=True,
    cos_lr=True,
    patience=5,
    pretrained=True,
    project="/content/runs_train",
    name="yolo11n_quick"
)
# Out:
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n_quick2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs_train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs_train/yolo11n_quick2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 144.6MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431647  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,815 parameters, 2,590,799 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.3±0.1 ms, read: 0.1±0.0 MB/s, size: 98.1 KB)
# train: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/train/labels.cache... 5805 images, 219 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5805/5805 7.6Mit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (6.6GB RAM): 100% ━━━━━━━━━━━━ 5805/5805 47.5it/s 2:02
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.4±0.1 ms, read: 0.1±0.0 MB/s, size: 72.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 762.5Kit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.6GB RAM): 100% ━━━━━━━━━━━━ 549/549 480.9it/s 1.1s
# Plotting labels to /content/runs_train/yolo11n_quick2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/runs_train/yolo11n_quick2
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      2.83G      1.359      1.799      1.093        240        640: 100% ━━━━━━━━━━━━ 363/363 5.8it/s 1:02
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 1.9it/s 9.5s
#                    all        549       5438      0.732      0.625      0.702      0.474
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      2.85G      1.231      1.006      1.034        280        640: 100% ━━━━━━━━━━━━ 363/363 9.8it/s 37.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.1it/s 2.2s
#                    all        549       5438      0.814       0.68      0.764        0.5
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      2.85G      1.199     0.8994      1.029        155        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.6it/s 2.1s
#                    all        549       5438      0.821      0.697      0.795      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      2.86G      1.166     0.8252      1.015        160        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.2s
#                    all        549       5438      0.826      0.712      0.803      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20      2.86G      1.143     0.7735      1.005        180        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.5it/s 2.1s
#                    all        549       5438      0.857      0.736      0.844      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20      2.86G      1.116     0.7458     0.9967        129        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.9it/s 2.3s
#                    all        549       5438      0.844       0.77      0.847      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20      2.86G      1.098     0.7124      0.988        165        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.832      0.795      0.865      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20      2.86G      1.074     0.6876     0.9793        133        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.5it/s 2.1s
#                    all        549       5438      0.847      0.798      0.875      0.616
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20      2.86G      1.061     0.6675     0.9735        197        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.6it/s 2.1s
#                    all        549       5438      0.883      0.804       0.88      0.641
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20      2.86G      1.036     0.6464     0.9653        203        640: 100% ━━━━━━━━━━━━ 363/363 10.3it/s 35.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.6it/s 2.1s
#                    all        549       5438      0.869      0.821      0.897      0.661
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20      2.86G      1.006     0.6121      0.962         93        640: 100% ━━━━━━━━━━━━ 363/363 10.2it/s 35.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.914      0.815      0.897      0.656
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20      2.86G     0.9763     0.5825     0.9507        126        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.876      0.846      0.912      0.669
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      2.86G     0.9576     0.5652     0.9444        114        640: 100% ━━━━━━━━━━━━ 363/363 10.4it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.891      0.861      0.914      0.674
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      2.86G     0.9391      0.549     0.9367         96        640: 100% ━━━━━━━━━━━━ 363/363 10.4it/s 34.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.4it/s 2.1s
#                    all        549       5438      0.904      0.852       0.92      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      2.86G     0.9171     0.5288     0.9279         97        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.9it/s 2.0s
#                    all        549       5438      0.912      0.847      0.922      0.695
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      2.86G     0.8967     0.5137     0.9226        105        640: 100% ━━━━━━━━━━━━ 363/363 10.4it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.5it/s 2.1s
#                    all        549       5438      0.919      0.861      0.928       0.71
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      2.86G     0.8815     0.5001     0.9164        141        640: 100% ━━━━━━━━━━━━ 363/363 10.4it/s 35.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.7it/s 2.1s
#                    all        549       5438      0.905      0.886      0.926      0.707
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      2.86G     0.8704     0.4923     0.9135        150        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 7.6it/s 2.4s
#                    all        549       5438      0.905      0.888      0.931      0.715
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      2.86G     0.8552     0.4841     0.9077        122        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.8it/s 2.1s
#                    all        549       5438      0.917      0.868      0.931      0.719
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      2.86G     0.8519     0.4796     0.9072        100        640: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.8it/s 2.0s
#                    all        549       5438      0.913      0.875      0.932      0.721
#
# 20 epochs completed in 0.219 hours.
# Optimizer stripped from /content/runs_train/yolo11n_quick2/weights/last.pt, 5.5MB
# Optimizer stripped from /content/runs_train/yolo11n_quick2/weights/best.pt, 5.5MB
#
# Validating /content/runs_train/yolo11n_quick2/weights/best.pt...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 4.8it/s 3.7s
#                    all        549       5438      0.913      0.875      0.932      0.721
#                    car        520       3842      0.913      0.915      0.965      0.758
#                bicycle        189        250      0.899      0.893      0.926      0.728
#                    bus         81        108      0.934      0.917      0.963      0.839
#              motorbike        331       1238      0.907      0.773      0.874      0.557
# Speed: 0.1ms preprocess, 0.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to /content/runs_train/yolo11n_quick2

# %%
from ultralytics import YOLO
model = YOLO('/content/yolo11n.pt')
results = model.train(
    data=('/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml'),
    epochs=20,
    imgsz=416,
    batch=16,
    device=0,
    workers=2,
    cache=True,
    amp=True,
    cos_lr=True,
    patience=5,
    pretrained=True,
    project="/content/runs_train",
    name="yolo11n_quick"
)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to '/content/yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 299.8MB/s 0.0s
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=/content/drive/MyDrive/dataset/3_data_multi_view_intersection/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=20, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=416, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/content/yolo11n.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolo11n_quick, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs_train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs_train/yolo11n_quick, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 112.2MB/s 0.0s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    111296  ultralytics.nn.modules.block.C3k2            [384, 128, 1, False]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     32096  ultralytics.nn.modules.block.C3k2            [256, 64, 1, False]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     86720  ultralytics.nn.modules.block.C3k2            [192, 128, 1, False]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    378880  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True]
#  23        [16, 19, 22]  1    431647  ultralytics.nn.modules.head.Detect           [5, [64, 128, 256]]
# YOLO11n summary: 181 layers, 2,590,815 parameters, 2,590,799 gradients, 6.4 GFLOPs
#
# Transferred 448/499 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.5±0.2 ms, read: 0.1±0.0 MB/s, size: 98.1 KB)
# train: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/train/labels.cache... 5805 images, 219 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5805/5805 8.4Mit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (2.8GB RAM): 100% ━━━━━━━━━━━━ 5805/5805 48.1it/s 2:01
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.3±0.0 ms, read: 0.1±0.0 MB/s, size: 72.2 KB)
# val: Scanning /content/drive/MyDrive/dataset/3_data_multi_view_intersection/val/labels.cache... 549 images, 17 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 549/549 768.8Kit/s 0.0s
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.3GB RAM): 100% ━━━━━━━━━━━━ 549/549 474.5it/s 1.2s
# Plotting labels to /content/runs_train/yolo11n_quick/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 81 weight(decay=0.0), 88 weight(decay=0.0005), 87 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to /content/runs_train/yolo11n_quick
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/20      1.26G      1.441      1.877      1.063        239        416: 100% ━━━━━━━━━━━━ 363/363 6.2it/s 58.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 2.0it/s 9.1s
#                    all        549       5438       0.74      0.548      0.624      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/20      1.27G      1.277      0.988     0.9959        277        416: 100% ━━━━━━━━━━━━ 363/363 10.5it/s 34.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.8it/s 2.0s
#                    all        549       5438      0.788      0.614      0.699      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/20      1.27G       1.24     0.9046      0.987        155        416: 100% ━━━━━━━━━━━━ 363/363 11.0it/s 32.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.1it/s 2.0s
#                    all        549       5438      0.793      0.623      0.724      0.477
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/20      1.29G      1.205     0.8455     0.9722        157        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.9it/s 2.0s
#                    all        549       5438      0.793      0.678      0.755      0.505
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/20       1.3G      1.185     0.7957     0.9659        180        416: 100% ━━━━━━━━━━━━ 363/363 11.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.0it/s 2.0s
#                    all        549       5438      0.838      0.704      0.794      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/20       1.3G      1.153     0.7637      0.958        128        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.0it/s 2.0s
#                    all        549       5438      0.799       0.72      0.801      0.551
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/20       1.3G       1.13     0.7363     0.9488        164        416: 100% ━━━━━━━━━━━━ 363/363 11.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.3it/s 1.9s
#                    all        549       5438      0.801      0.728      0.802      0.549
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/20       1.3G      1.114     0.7147     0.9428        132        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.0it/s 2.0s
#                    all        549       5438      0.844      0.754      0.822      0.571
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/20       1.3G      1.103     0.6955     0.9404        197        416: 100% ━━━━━━━━━━━━ 363/363 11.1it/s 32.8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.1it/s 2.0s
#                    all        549       5438      0.847      0.755      0.834      0.585
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/20       1.3G      1.076     0.6722      0.932        202        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.2it/s 2.0s
#                    all        549       5438      0.828      0.742      0.821      0.585
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/20       1.3G      1.042     0.6386     0.9277         93        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.2it/s 2.0s
#                    all        549       5438      0.858      0.754      0.835      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/20       1.3G      1.013     0.6068      0.918        126        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.0it/s 2.0s
#                    all        549       5438      0.861      0.786      0.858      0.615
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/20      1.32G     0.9923     0.5942     0.9126        112        416: 100% ━━━━━━━━━━━━ 363/363 11.2it/s 32.4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.1it/s 2.0s
#                    all        549       5438      0.865      0.796      0.864      0.628
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/20      1.32G     0.9723     0.5766     0.9066         94        416: 100% ━━━━━━━━━━━━ 363/363 11.3it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.4it/s 1.9s
#                    all        549       5438      0.888      0.788      0.868      0.632
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/20      1.32G     0.9556     0.5588     0.8997         97        416: 100% ━━━━━━━━━━━━ 363/363 11.4it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.1it/s 2.0s
#                    all        549       5438      0.899      0.807      0.878      0.646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/20      1.32G     0.9354     0.5451     0.8954        105        416: 100% ━━━━━━━━━━━━ 363/363 11.3it/s 32.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.2it/s 2.0s
#                    all        549       5438       0.92      0.801      0.881      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/20      1.32G     0.9236     0.5332     0.8909        140        416: 100% ━━━━━━━━━━━━ 363/363 11.3it/s 32.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.1it/s 2.0s
#                    all        549       5438      0.918      0.802      0.883      0.649
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/20      1.32G     0.9103      0.525     0.8885        148        416: 100% ━━━━━━━━━━━━ 363/363 11.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.9it/s 2.0s
#                    all        549       5438      0.908      0.812      0.889      0.658
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/20      1.32G     0.8993     0.5162     0.8855        122        416: 100% ━━━━━━━━━━━━ 363/363 11.4it/s 31.9s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 9.2it/s 2.0s
#                    all        549       5438      0.905      0.809      0.889       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/20      1.32G     0.8945     0.5123     0.8852         99        416: 100% ━━━━━━━━━━━━ 363/363 11.1it/s 32.6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 8.9it/s 2.0s
#                    all        549       5438      0.907      0.817       0.89      0.661
#
# 20 epochs completed in 0.203 hours.
# Optimizer stripped from /content/runs_train/yolo11n_quick/weights/last.pt, 5.4MB
# Optimizer stripped from /content/runs_train/yolo11n_quick/weights/best.pt, 5.4MB
#
# Validating /content/runs_train/yolo11n_quick/weights/best.pt...
# Ultralytics 8.3.239 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA L4, 22693MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 18/18 5.2it/s 3.4s
#                    all        549       5438      0.905      0.817      0.891       0.66
#                    car        520       3842      0.898       0.88      0.944      0.712
#                bicycle        189        250      0.907      0.792      0.864      0.641
#                    bus         81        108      0.915      0.898      0.945      0.813
#              motorbike        331       1238      0.899      0.698      0.809      0.473
# Speed: 0.1ms preprocess, 0.4ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/runs_train/yolo11n_quick
